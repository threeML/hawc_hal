# %%
from threeML import *

# %matplotlib notebook
# Out:
# Configuration read from /home/giacomov/.threeML/threeML_config.yml
# Plotter is MatPlotlib

# %%
from ts_map import ParallelTSmap

# %%
data_dir = "/home/giacomov/science/hawc/data/"

mtfile = os.path.join(data_dir, "maptree_1024.root")
rsfile = os.path.join(data_dir, "response.root")

ra_c = 83.633083
dec_c = 22.014500

# Mrk 501
ra_c = 253.467569
dec_c = 39.760169

ts_map_p = ParallelTSmap(mtfile, rsfile, ra_c, dec_c, 25, 24, 0.006, roi_radius=3.0)

with parallel_computation():

    res = ts_map_p.go()

# jl_set = JointLikelihoodSet(ts_map_p.get_data, ts_map_p.get_model, ras.shape[0] * decs.shape[0])

# jl_set.set_minimizer("ROOT")

# import time
# start = time.time()

# with parallel_computation(start_cluster=True):

#     parameters, likelihood_values = jl_set.go(continue_on_failure=False)

# #%prun parameters, likelihood_values = jl_set.go(continue_on_failure=False)

# print(time.time() - start)
# Out:
# Maximum distance from center: 0.104 deg
# Creating singleton for /home/giacomov/science/hawc/data/response.root
# We will start the ipyparallel cluster with this command line:
# ipcluster start
# Waiting for connection file: ~/.ipython/profile_default/security/ipcontroller-client.json
# 8 engines are active
# Maximum TS is 428.03 at (R.A., Dec) = (253.487, 39.772)
#
# Shutting down ipcluster...

# %%
# %debug
# Out:
# ERROR:root:No traceback has been produced, nothing to debug.

# %%
fig = ts_map_p.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ts_map_p.to_fits("tsmap.fits")
